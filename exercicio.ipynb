# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorWeizenmann/pcd-aula03/blob/main/exercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = str (input ("Qual seu nome? "))
nota1 = float (input ("Digite a primeira nota: "))
nota2 = float (input ("Digite a segunda nota: "))
nota3 = float (input ("Digite a terceira nota: "))
total = ((nota1 + nota2 + nota3) / 3)
print(nome, "sua nota final é:", total)
# Out:
# Qual seu nome? Victor
# Digite a primeira nota: 7.5
# Digite a segunda nota: 8.5
# Digite a terceira nota: 7.5
# Victor sua nota final é de: 7.833333333333333
